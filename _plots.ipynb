# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams["figure.figsize"] = [17, 7]

# %%
## out plot will be a matrix of probabilities

# %%
data = np.zeros((100,100))

# %%
indxs = [np.random.randint(100) for x in range(50)]
data[0, indxs] = 1

# %%
sns.heatmap(data)
plt.show()

# %%
sns.kdeplot(x, y)
plt.show()
